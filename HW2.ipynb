# %%
#Задание 1 Необходимо выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную.
text = "При регистрации на сервисе у вас будут расширены ограничения проверки, предназначенные для гостей, и вы получите возможность проверять гораздо большее количество текстов с помощью нашего сервиса плагиат онлайн"
#удаляем знаки препинания из текста и разбиваем его на слова
from string import punctuation
m = text.split()
wordss = [w.strip(punctuation) for w in words]
print(wordss)
#Создаем список биграм 
bigrams = []
b = len(wordss)
for m in range (b -1):
    p = wordss[m] + ' ' + wordss[m + 1]
    print(p)
    bigrams.append(p)
# Out:
# ['При', 'регистрации', 'на', 'сервисе', 'у', 'вас', 'будут', 'расширены', 'ограничения', 'проверки', 'предназначенные', 'для', 'гостей', 'и', 'вы', 'получите', 'возможность', 'проверять', 'гораздо', 'большее', 'количество', 'текстов', 'с', 'помощью', 'нашего', 'сервиса', 'плагиат', 'онлайн']
# При регистрации
# регистрации на
# на сервисе
# сервисе у
# у вас
# вас будут
# будут расширены
# расширены ограничения
# ограничения проверки
# проверки предназначенные
# предназначенные для
# для гостей
# гостей и
# и вы
# вы получите
# получите возможность
# возможность проверять
# проверять гораздо
# гораздо большее
# большее количество
# количество текстов
# текстов с
# с помощью
# помощью нашего
# нашего сервиса
# сервиса плагиат
# плагиат онлайн

# %%
#Задание 3 Скопировать текст, сохранить его в переменную.
cat = '''Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!'''
#Узнать длину текста в символах.
print(len(cat))
#Очистить текст от пунктуации, используя list compehensions. На выходе должен получиться список слов.
from string import punctuation
parts = cat.split()
cats = [i.strip(punctuation) for i in parts]
print(cats)
#Объединить слова из получившегося списка в строку через пробел.
cat2 = ' '.join(cats)
print(cat2)
#С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
cat3 = [ parts if cat2.islower() else w.lower() for w in cats ]
print(cat3)
#Узнать длину текста в словах.
print(len(parts))
#Узнать количество уникальных слов.
print(len(set(parts)))
#Распечатать последние 10 слов.
print(cat3[-10:])
#Соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки.
cats4 = '\n'.join(cats)
print('\n'.join(cats))
#Распечатать с 20 по 30 символ этой строки (включительно).
cats5 = cats4[20:30]
print(cats5)
# Out:
# 270
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит
# ...

# %%
#Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы.
bigramss = []
bb = len(cats)
for m in range (bb -1):
    pp = cats[m] + ' ' + cats[m + 1]
    print(pp)
    bigramss.append(pp)
    bbigrams = tuple(bigramss)
print(bbigrams)
#считаем количество каждой биграммы
for m in bbigrams:
    print(bbigrams.count(m))
# Out:
# Несчастная кошка
# кошка порезала
# порезала лапу
# лапу Сидит
# Сидит и
# и ни
# ни шагу
# шагу не
# не может
# может ступить
# ступить Скорей
# Скорей чтобы
# чтобы вылечить
# вылечить кошкину
# кошкину лапу
# лапу Воздушные
# Воздушные шарики
# шарики надо
# надо купить
# купить И
# И сразу
# сразу столпился
# столпился народ
# народ на
# на дороге
# дороге Шумит
# Шумит и
# и кричит
# кричит и
# и на
# на кошку
# кошку глядит
# глядит А
# А кошка
# кошка отчасти
# отчасти идет
# идет по
# по дороге
# дороге Отчасти
# Отчасти по
# по воздуху
# воздуху плавно
# плавно летит
# ...

# %%
#Задание 2. 

# сначала нужно обязательно импортировать модуль!
import os
# посмотрим, в какой папке мы находимся
print(os.getcwd())
for file in os.listdir('.'): # точка = текущая папка
    print(file)
    
    
#Напечатаем список всех файлов содержащихся внутри папок по заданному пути    
for root, dirs, files in os.walk('/Users/mariamironenko/Desktop/python-dh-hw'):
    for name in files:
        fullname = os.path.join(root, name)
        print(fullname)
# Out:
# /Users/mariamironenko/Desktop/python-dh-hw
# .DS_Store
# .git
# .ipynb_checkpoints
# HW1.ipynb
# HW2.ipynb
# HW2011110101.ipynb
# poems
# README.md
# /Users/mariamironenko/Desktop/python-dh-hw/.DS_Store
# /Users/mariamironenko/Desktop/python-dh-hw/HW1.ipynb
# /Users/mariamironenko/Desktop/python-dh-hw/HW2.ipynb
# /Users/mariamironenko/Desktop/python-dh-hw/HW2011110101.ipynb
# /Users/mariamironenko/Desktop/python-dh-hw/README.md
# /Users/mariamironenko/Desktop/python-dh-hw/.git/COMMIT_EDITMSG
# /Users/mariamironenko/Desktop/python-dh-hw/.git/config
# /Users/mariamironenko/Desktop/python-dh-hw/.git/description
# /Users/mariamironenko/Desktop/python-dh-hw/.git/FETCH_HEAD
# /Users/mariamironenko/Desktop/python-dh-hw/.git/HEAD
# /Users/mariamironenko/Desktop/python-dh-hw/.git/index
# /Users/mariamironenko/Desktop/python-dh-hw/.git/ORIG_HEAD
# /Users/mariamironenko/Desktop/python-dh-hw/.git/packed-refs
# /Users/mariamironenko/Desktop/python-dh-hw/.git/hooks/applypatch-msg.sample
# ...

# %%
#Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt 

with open('poem.txt', 'a', encoding='utf-8') as f:
    for root, dirs, files in os.walk('/Users/mariamironenko/Desktop/python-dh-hw/poems'):
        f.write(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5db1bec299c5> in <module>()
#       3 with open('poem.txt', 'a', encoding='utf-8') as f:
#       4     for root, dirs, files in os.walk('/Users/mariamironenko/Desktop/python-dh-hw/poems'):
# ----> 5         f.write(text)
#       6
#       7
#
# NameError: name 'text' is not defined
