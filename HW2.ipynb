# %%
#Задание 1
text = "При регистрации на сервисе у вас будут расширены ограничения проверки, предназначенные для гостей, и вы получите возможность проверять гораздо большее количество текстов с помощью нашего сервиса плагиат онлайн"
#удаляем знаки препинания из текста и разбиваем его на слова
from string import punctuation
m = text.split()
wordss = [w.strip(punctuation) for w in words]
print(wordss)
#Создаем список биграм 
bigrams = []
b = len(wordss)
for m in range (b -1):
    p = wordss[m] + ' ' + wordss[m + 1]
    print(p)
    bigrams.append(p)
# Out:
# ['При', 'регистрации', 'на', 'сервисе', 'у', 'вас', 'будут', 'расширены', 'ограничения', 'проверки', 'предназначенные', 'для', 'гостей', 'и', 'вы', 'получите', 'возможность', 'проверять', 'гораздо', 'большее', 'количество', 'текстов', 'с', 'помощью', 'нашего', 'сервиса', 'плагиат', 'онлайн']
# При регистрации
# регистрации на
# на сервисе
# сервисе у
# у вас
# вас будут
# будут расширены
# расширены ограничения
# ограничения проверки
# проверки предназначенные
# предназначенные для
# для гостей
# гостей и
# и вы
# вы получите
# получите возможность
# возможность проверять
# проверять гораздо
# гораздо большее
# большее количество
# количество текстов
# текстов с
# с помощью
# помощью нашего
# нашего сервиса
# сервиса плагиат
# плагиат онлайн

# %%
#Задание 3
cat = '''Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!'''
#Узнаем длину строки в символах
print(len(cat))
#Урезаем пунктуацию и выводим список слов (пункт 3)
from string import punctuation
parts = cat.split()
cats = [i.strip(punctuation) for i in parts]
print(cats)
#объединяем с пробелами
cat2 = ' '.join(cats)
print(cat2)
#создаем список в нижнем регистре
cat3 = [ parts if cat2.islower() else w.lower() for w in cats ]
print(cat3)
#узнаем длину текста в словах
print(len(parts))
#узнаем количество уникальных слов
print(len(set(parts)))
#печатаем последние 10 слов
print(cat3[-10:])
#соединяем котов из пункта 3 в строку и выводим через знак переноса строки
xxx = '\n'.join(cats)
print('\n'.join(cats))
# Out:
# 270
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит
# ...

# %%
#печатаем с 20 по 30 символ из предыдущей строки
xx = xxx[20:30]
print(xx)

# %%
#создаем список биграмм и проверяем их уникальность
bigramss = []
bb = len(cats)
for m in range (bb -1):
    pp = cats[m] + ' ' + cats[m + 1]
    print(pp)
    bigramss.append(pp)
    bbigrams = tuple(bigramss)
print(bbigrams)
#считаем количество каждой биграммы
for m in bbigrams:
    print(bbigrams.count(m))
# Out:
# Несчастная кошка
# кошка порезала
# порезала лапу
# лапу Сидит
# Сидит и
# и ни
# ни шагу
# шагу не
# не может
# может ступить
# ступить Скорей
# Скорей чтобы
# чтобы вылечить
# вылечить кошкину
# кошкину лапу
# лапу Воздушные
# Воздушные шарики
# шарики надо
# надо купить
# купить И
# И сразу
# сразу столпился
# столпился народ
# народ на
# на дороге
# дороге Шумит
# Шумит и
# и кричит
# кричит и
# и на
# на кошку
# кошку глядит
# глядит А
# А кошка
# кошка отчасти
# отчасти идет
# идет по
# по дороге
# дороге Отчасти
# Отчасти по
# по воздуху
# воздуху плавно
# плавно летит
# ...
