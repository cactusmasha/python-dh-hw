# %%
#Задание 1.
#Задание 1. Напишите функцию, которая будет читать файл, лемматизировать текст с помощью pymystem3 и записывать результат в новый файл. У функции должно бы два аргумента: путь к исходному файлу и путь к файлу с лемматизированным текстом. Вызов функции тоже должен быть прописан в решении.
def sounds (reading):
    with open('poem.txt', 'r', encoding='utf-8') as f:
        poem = f.read()
    from pymystem3 import Mystem
    m = Mystem()
    lemmas = m.lemmatize(poem)
    lm = (type(lemmas))
    ls = (''.join(lemmas))
    with open('literary_lemmas.txt', 'w', encoding='utf-8') as f:
        f.write(str(lm))
        f.write(str(ls))
#Читаем файл и записываем его в список 
    with open('poem.txt', 'r', encoding='utf-8') as f:
        lines = f.readlines()
    print(lines)
# вызов функции        
sounds(input("Введите наименование функции"))
# Out:
# Введите наименование функцииreading
# ...

# %%
#Установка nltk для задания 2
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
#Задание 2.Очистите лемматизированный текст от стоп-слов 
from nltk.corpus import stopwords
sw = stopwords.words('russian')

# %%
#Очистите лемматизированный текст от стоп-слов.
with open('literary_lemmas.txt', 'r', encoding='utf-8') as f:
    literary = f.read()
    print(literary)
    filt = [w for w in word_tokenize(literary) if w not in sw]
    print(filt)
    m = str(filt)
    print(m)
# Out:
# <class 'list'>у вяземский быть квартира окно на тверской бульвар. пушкин очень любить ходить к он в гость. прийти - и сразу прыг на подоконник, свешиваться из окно и смотреть. чай он тоже туда, на окно, подавать. иной раз там и заночевать. он даже матрац купить специальный, только он он не признавать."к что, - говорить,- такой роскошь?". и спихивать матрац с подоконник. а потом весь ночь вертеться, спать не давать.
#
# гоголь переодеваться пушкин, приходить к пушкин и позвонить.
# пушкин открывать он и кричать: "смотреть, арина родионовна, я приходить!".
#
# лермонтов хотеть у пушкин жена уводить. на кавказ. все смотреть на она из-за колонна, смотреть... вдруг устыжаться свой желание. "пушкин, - думать, - зеркало русский революция, а я свинья". пойти, вставать перед он на колено и говорить: "пушкин, где твой кинжал? вот грудь мой". пушкин очень смеяться.
#
# однажды пушкин стреляться с гоголь. пушкин говорить:
# - стрелять первый ты.
# - как я? нет, ты.
# ...

# %%
#Удаляем пунктуацию
import string
for w in string.punctuation:
    s= m.replace(w,"")
print(s)
# Out:
# ['<', 'class', "'list", "'", '>', 'вяземский', 'квартира', 'окно', 'тверской', 'бульвар', '.', 'пушкин', 'очень', 'любить', 'ходить', 'гость', '.', 'прийти', '-', 'сразу', 'прыг', 'подоконник', ',', 'свешиваться', 'окно', 'смотреть', '.', 'чай', 'туда', ',', 'окно', ',', 'подавать', '.', 'иной', 'заночевать', '.', 'матрац', 'купить', 'специальный', ',', 'признавать', '.', '``', ',', '-', 'говорить', ',', '-', 'роскошь', '?', "''", '.', 'спихивать', 'матрац', 'подоконник', '.', 'весь', 'ночь', 'вертеться', ',', 'спать', 'давать', '.', 'гоголь', 'переодеваться', 'пушкин', ',', 'приходить', 'пушкин', 'позвонить', '.', 'пушкин', 'открывать', 'кричать', ':', '``', 'смотреть', ',', 'арина', 'родионовна', ',', 'приходить', '!', "''", '.', 'лермонтов', 'хотеть', 'пушкин', 'жена', 'уводить', '.', 'кавказ', '.', 'смотреть', 'из-за', 'колонна', ',', 'смотреть', '...', 'устыжаться', 'свой', 'желание', '.', '``', 'пушкин', ',', '-', 'думать', ',', '-', 'зеркало', 'русский', 'революция', ',', 'сви
# ...

# %%
#Удаляем пунктуацию
exclude = set(string.punctuation)
s = ''.join(w for w in m if w not in exclude)
words = s.split()
print(words)
# Out:
# ['class', 'list', 'вяземский', 'квартира', 'окно', 'тверской', 'бульвар', 'пушкин', 'очень', 'любить', 'ходить', 'гость', 'прийти', 'сразу', 'прыг', 'подоконник', 'свешиваться', 'окно', 'смотреть', 'чай', 'туда', 'окно', 'подавать', 'иной', 'заночевать', 'матрац', 'купить', 'специальный', 'признавать', 'говорить', 'роскошь', 'спихивать', 'матрац', 'подоконник', 'весь', 'ночь', 'вертеться', 'спать', 'давать', 'гоголь', 'переодеваться', 'пушкин', 'приходить', 'пушкин', 'позвонить', 'пушкин', 'открывать', 'кричать', 'смотреть', 'арина', 'родионовна', 'приходить', 'лермонтов', 'хотеть', 'пушкин', 'жена', 'уводить', 'кавказ', 'смотреть', 'изза', 'колонна', 'смотреть', 'устыжаться', 'свой', 'желание', 'пушкин', 'думать', 'зеркало', 'русский', 'революция', 'свинья', 'пойти', 'вставать', 'колено', 'говорить', 'пушкин', 'твой', 'кинжал', 'грудь', 'пушкин', 'очень', 'смеяться', 'однажды', 'пушкин', 'стреляться', 'гоголь', 'пушкин', 'говорить', 'стрелять', 'первый', 'ах', 'становиться', 'стреля
# ...

# %%
#посчитайте ipm для оставшихся
n = len(words)
e = [words.count(w) for w in words if w.isalpha]
for w in words:
    imp = ((words.count(w)/len(words))*10000000)
    print(imp)
# Out:
# 5820.721769499418
# 5820.721769499418
# 29103.608847497093
# 5820.721769499418
# 69848.66123399301
# 69848.66123399301
# 69848.66123399301
# 343422.5844004657
# 98952.2700814901
# 116414.43538998837
# 11641.443538998836
# 40745.052386495925
# 5820.721769499418
# 17462.165308498254
# 5820.721769499418
# 17462.165308498254
# 5820.721769499418
# 69848.66123399301
# 40745.052386495925
# 29103.608847497093
# 5820.721769499418
# 69848.66123399301
# 17462.165308498254
# 5820.721769499418
# 5820.721769499418
# 11641.443538998836
# 23282.88707799767
# 5820.721769499418
# 5820.721769499418
# 104772.99185098952
# 5820.721769499418
# 5820.721769499418
# 11641.443538998836
# 17462.165308498254
# 40745.052386495925
# 29103.608847497093
# 5820.721769499418
# 11641.443538998836
# 34924.33061699651
# 180442.37485448195
# 52386.49592549476
# 343422.5844004657
# 69848.66123399301
# 343422.5844004657
# 11641.443538998836
# 343422.5844004657
# 11641.443538998836
# 29103.608847497093
# 40745.052386495925
# ...

# %%
# записываем результат в переменную, как в примере выше
words = [w for w in sent.split() if w.isalpha()]
print("the cat is on the mat".count("the"))
for w in words:
    e = words.count(w)

# %%
#Выведите 20 самых частотных по этому параметру слов.
counts = {}
for word in words:
    if word in counts:
        counts[word] += 1
    else:
        counts[word] = 1
        sorted_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
print(sorted_counts[:20])
# Out:
# [('пушкин', 59), ('толстой', 33), ('гоголь', 31), ('однажды', 29), ('лев', 25), ('любить', 20), ('достоевский', 20), ('говорить', 18), ('очень', 17), ('тургенев', 16), ('ребенок', 15), ('это', 15), ('царствие', 15), ('небесный', 15), ('окно', 12), ('тверской', 12), ('бульвар', 12), ('приходить', 12), ('лермонтов', 12), ('думать', 12)]

# %%
#Задание 3.Сделайте полный морфологический разбор исходного текста. 
import json
analis = m.analyze(poem)
with open('lemma.json', 'w', encoding='utf-8') as f:
    json.dump(analis, f, ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-5c171e09a1ce> in <module>()
#       1 #Задание 3.Сделайте полный морфологический разбор исходного текста.
#       2 import json
# ----> 3 analis = m.analyze(poem)
#       4 with open('lemma.json', 'w', encoding='utf-8') as f:
#       5     json.dump(analis, f, ensure_ascii=False)
#
# AttributeError: 'str' object has no attribute 'analyze'

# %%
#Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение).
d = dict()
d = m.analize(w for w in filt if w.isalfa())
print(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-3568565af054> in <module>()
#       1 #Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение).
#       2 d = dict()
# ----> 3 d = m.analize(w for w in filt if w.isalfa())
#       4 print(d)
#
# AttributeError: 'str' object has no attribute 'analize'

# %%
morf = m.analyze(w for w in pp if w.isalpha())
grammar = morf[0]['analysis'][0]['gr']
print(grammar)
m[0]['analysis'][0]['gr']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-f67b2ba5bcc0> in <module>()
# ----> 1 morf = m.analyze(w for w in pp if w.isalpha())
#       2 grammar = morf[0]['analysis'][0]['gr']
#       3 print(grammar)
#       4 m[0]['analysis'][0]['gr']
#
# AttributeError: 'str' object has no attribute 'analyze'
